# %% [markdown]
# # Quickstart: Training with ModelTrainee
#
# Training deep learning models — such as disentangled RNNs (disRNN) or standard architectures like GRU and LSTM — as cognitive models of behavioral data requires robust infrastructure for serializing and deserializing model state across long-running, interruptible workflows. The `disRNN_MP` package addresses this with `ModelTrainee`, a database-backed ORM class that bundles everything needed to define, train, and resume a model: architecture specification, optimizer and dataset configuration, parameter snapshots, and training metrics. Because all state is persisted to a SQLite (or other SQL) database via SQLAlchemy, training runs can be checkpointed automatically, resumed after interruption on the same or a different machine, and parallelized across multiple workers querying the same database for unfinished jobs.
#
# This notebook demonstrates how to:
# 1. Define a disRNN model with **two-phase training** (no penalty → with penalty) using `ModelTrainee`
# 2. Persist the training configuration to a SQLite database
# 3. Train the model with automatic checkpointing
# 4. Resume training after interruption (via `GracefulKiller`)
# 5. Inspect training results
# 6. Train a standard **GRU** model for comparison

# %%
import os
os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"] = "false"

from pathlib import Path
from sqlalchemy import create_engine, select
from sqlalchemy.orm import Session

from disRNN_MP.rnn.train_db import Base, ModelTrainee, trainingSession

# %% [markdown]
# ## Create SQLite database
#
# ModelTrainee uses SQLAlchemy to persist model definitions, training sessions, and checkpoints.

# %%
engine = create_engine('sqlite:///quickstart_training.db', echo=False)
Base.metadata.create_all(engine)

# %% [markdown]
# ## Define disRNN model and two-phase training
#
# **Two-phase training strategy:** disRNN models benefit from a two-phase approach:
# 1. **Phase 1 (no penalty):** Train with `penalty_scale=0` so the model can learn the data without constraints.
# 2. **Phase 2 (with penalty):** Add a sparsity penalty (`penalty_scale > 0`) to encourage disentangled, interpretable latent representations.
#
# We use Hydra-style `dry_*` configs (dictionaries with `_target_` keys) to specify the model, optimizer, loss function, and dataset, which allows easily reloading the trained models in a new python session to continue training or for analysis.
#
# Each phase is represented as a separate `trainingSession` in the `sessions` list. The trainer executes them sequentially, picking up where the previous session left off.

# %%
# Resolve data path relative to the repo root
data_path = Path('../data/mp_beh_m18_500completed.npy').resolve().as_posix()

# The ModelTrainee class represent an entry point to a model: it points to a architecture definition
# that will be initialized with certain hyperparameters, also hold references to all planned training
# sessions and trained snapshots.
mt = ModelTrainee(
    dry_model={
        '_target_': 'disRNN_MP.rnn.disrnn_def.make_transformed_disrnn',
        'latent_size': 5,
        'update_mlp_shape': [3, 3],
        'choice_mlp_shape': [2],
        'target_size': 2,
        'eval_mode': False,
    },
)

# Shared config for both sessions
shared_session_kwargs = dict(
    dry_optimizer={
        '_target_': 'optax.adam',
        'learning_rate': 1e-3,
    },
    dry_make_param_metric={
        '_target_': 'disRNN_MP.rnn.disrnn_def.make_param_metric_expLL',
        '_partial_': True,
    },
    dry_datasets={
        '_target_': 'disRNN_MP.dataset.train_test_datasets',
        'dat_or_path': data_path,
        'n_sess_sample': 42,
        'seed': 5,
    },
)

# Phase 1: train without penalty to let the model learn data patterns unconstrained
se1 = trainingSession(
    **shared_session_kwargs,
    dry_make_train_step={
        '_target_': 'disRNN_MP.rnn.disrnn_def.make_train_step',
        '_partial_': True,
        'penalty_scale': 0,
    },
    n_step=200,
    steps_per_block=10,
)

# Phase 2: add sparsity penalty to encourage disentangled representations
se2 = trainingSession(
    **shared_session_kwargs,
    dry_make_train_step={
        '_target_': 'disRNN_MP.rnn.disrnn_def.make_train_step',
        '_partial_': True,
        'penalty_scale': 1e-3,
    },
    n_step=300,
    steps_per_block=10,
)

# The `sessions` attribute is an ordered list that plans training sessions to execute sequentially.
# The trainer will run Phase 1 first, then continue into Phase 2 from where Phase 1 left off.
mt.sessions = [se1, se2]

# %% [markdown]
# ## Commit to database

# %%
with Session(engine) as sess:
    sess.add(mt)
    sess.commit()

# %% [markdown]
# ## Train the model
#
# Load the `ModelTrainee` from the database and call `.train()`. Training progress is
# automatically checkpointed to the database every `steps_per_block` steps.

# %%
sess = Session(engine, expire_on_commit=False)
mt = sess.execute(select(ModelTrainee).where(ModelTrainee.id == 1)).scalar_one()
ret = mt.train(sess, 'worker1')
# Out:
# step 1 is done with loss: 1.5024e+04 (Time: 9.6s)
# step 11 is done with loss: 1.4651e+04 (Time: 10.9s)
# step 21 is done with loss: 1.4582e+04 (Time: 12.2s)
# step 31 is done with loss: 1.4569e+04 (Time: 13.5s)
# step 41 is done with loss: 1.4539e+04 (Time: 14.8s)
# step 51 is done with loss: 1.4522e+04 (Time: 16.1s)
# step 61 is done with loss: 1.4503e+04 (Time: 17.4s)
# step 71 is done with loss: 1.4490e+04 (Time: 18.7s)
# [2026-03-04T23:13:23.675]: received signal 2
# step 81 is done with loss: 1.4473e+04 (Time: 20.0s)
# [2026-03-04T23:13:23.760]: terminated at step 81

# %% [markdown]
# ## Resumable training
#
# If training is interrupted (e.g., via Ctrl-C), `GracefulKiller` catches the signal and
# saves the current state to the database. You can then reload and call `.train()` again
# to resume from the last checkpoint.
#
# Try interrupting the cell above with Ctrl-C during training, then run the cell below
# to resume.

# %%
sess = Session(engine, expire_on_commit=False)
mt = sess.execute(select(ModelTrainee).where(ModelTrainee.id == 1)).scalar_one()
ret = mt.train(sess, 'worker1')  # resumes from last saved step
# Out:
# step 91 is done with loss: 1.4461e+04 (Time: 9.1s)
# step 101 is done with loss: 1.4449e+04 (Time: 10.4s)
# step 111 is done with loss: 1.4435e+04 (Time: 11.7s)
# step 121 is done with loss: 1.4423e+04 (Time: 13.0s)
# step 131 is done with loss: 1.4406e+04 (Time: 14.3s)
# [2026-03-04T23:13:48.144]: received signal 2
# [2026-03-04T23:13:48.148]: terminated at step 138

# %% [markdown]
# ## Inspect training results

# %%
for rec in mt.records:
    print(f"step {rec.step}: train={rec.train_metric:.4f}, test={rec.test_metric:.4f}")
# Out:
# step 1: train=0.4902, test=0.4897
# step 11: train=0.4981, test=0.4976
# step 21: train=0.4993, test=0.4988
# step 31: train=0.4998, test=0.4993
# step 41: train=0.5004, test=0.4999
# step 51: train=0.5008, test=0.5003
# step 61: train=0.5013, test=0.5008
# step 71: train=0.5016, test=0.5011
# step 81: train=0.5020, test=0.5015
# step 91: train=0.5023, test=0.5018
# step 101: train=0.5026, test=0.5021
# step 111: train=0.5029, test=0.5024
# step 121: train=0.5032, test=0.5027
# step 131: train=0.5036, test=0.5031

# %% [markdown]
# ---
#
# # Training a standard GRU model
#
# This section demonstrates training a plain GRU (Gated Recurrent Unit) model for comparison.
#
# Key differences from disRNN:
# - **Architecture:** Standard GRU network (`disRNN_MP.rnn.network_defs.make_GRU`) instead of a disentangled RNN
# - **Loss function:** Simple categorical cross-entropy (`loss_type='categorical'`), no bottleneck penalty term
# - **Training:** Uses mini-batch SGD with random batch sampling; single training phase (no penalty schedule needed)
# - **Default inheritance:** Optimizer, dataset, and metric are set as `default_*` fields on `ModelTrainee`, so all training sessions inherit them automatically

# %%
# The `model=` keyword is a convenience alias for `dry_model=`.
# Here we use `transform_hkRNN` which wraps any Haiku RNNCore for use with ModelTrainee.
mt_gru = ModelTrainee(
    model={
        '_target_': 'disRNN_MP.rnn.utils.transform_hkRNN',
        'hkRNN': {
            '_target_': 'disRNN_MP.rnn.network_defs.make_GRU',
            'hidden_size': 16,
        },
    },
    init_rand_seed=0,
    # Setting default_* fields on ModelTrainee means all training sessions
    # inherit these configs without repeating them per session.
    default_make_param_metric={
        '_target_': 'disRNN_MP.rnn.utils.make_param_metric_expLL',
        '_partial_': True,
        'n_action': 2,
    },
    default_optimizer={
        '_target_': 'optax.adam',
        'learning_rate': 1e-3,
    },
    default_datasets={
        '_target_': 'disRNN_MP.dataset.train_test_datasets',
        'dat_or_path': data_path,
        'n_sess_sample': 42,
        'seed': 5,
        'batch_size': 10,
        'train_batch_samp': 'random',
    },
    description='16-unit GRU quickstart example',
)

# Single training session — only the train step function needs to be specified;
# optimizer, dataset, and metric are inherited from the ModelTrainee defaults.
gru_session = trainingSession(
    dry_make_train_step={
        '_target_': 'disRNN_MP.rnn.utils.make_train_step',
        '_partial_': True,
        'loss_type': 'categorical',
    },
    n_step=200,
    steps_per_block=10,
)

mt_gru.sessions.append(gru_session)

# %% [markdown]
# ## Commit and train GRU model

# %%
with Session(engine) as db_sess:
    db_sess.add(mt_gru)
    db_sess.commit()

sess = Session(engine, expire_on_commit=False)
mt_gru = sess.execute(select(ModelTrainee).where(ModelTrainee.id == 2)).scalar_one()
ret = mt_gru.train(sess, 'worker1')
# Out:
# step 1 is done with loss: 4.1596e+03 (Time: 2.4s)
# step 11 is done with loss: 3.7415e+03 (Time: 2.8s)
# step 21 is done with loss: 3.6026e+03 (Time: 3.2s)
# step 31 is done with loss: 3.4769e+03 (Time: 3.6s)
# step 41 is done with loss: 3.4429e+03 (Time: 4.0s)
# step 51 is done with loss: 3.4525e+03 (Time: 4.4s)
# step 61 is done with loss: 3.4367e+03 (Time: 4.8s)
# step 71 is done with loss: 3.4356e+03 (Time: 5.1s)
# step 81 is done with loss: 3.4375e+03 (Time: 5.5s)
# step 91 is done with loss: 3.4307e+03 (Time: 5.9s)
# step 101 is done with loss: 3.4223e+03 (Time: 6.3s)
# step 111 is done with loss: 3.4163e+03 (Time: 6.7s)
# [2026-03-04T23:14:17.503]: received signal 2
# [2026-03-04T23:14:17.504]: terminated at step 113

# %% [markdown]
# ## Inspect GRU training results

# %%
for rec in mt_gru.records:
    print(f"step {rec.step}: train={rec.train_metric:.4f}, test={rec.test_metric:.4f}")
# Out:
# step 1: train=0.4435, test=0.4433
# step 11: train=0.4708, test=0.4706
# step 21: train=0.4888, test=0.4885
# step 31: train=0.4983, test=0.4980
# step 41: train=0.5017, test=0.5014
# step 51: train=0.5024, test=0.5021
# step 61: train=0.5027, test=0.5024
# step 71: train=0.5031, test=0.5029
# step 81: train=0.5036, test=0.5034
# step 91: train=0.5039, test=0.5038
# step 101: train=0.5043, test=0.5041
# step 111: train=0.5046, test=0.5045
